# %% [markdown]
# # Training ML Model on SageMaker with Minute Bar Derived from FinSpace
#
# After generating minute bar or daily bar from FinSpace kdb+, you can train an ML model and develop a trading strategy. This example demonstrates how to load historical minute bar data and train an XGBoost model easily on SageMaker. The procedure is as follows:
#
# ##### 1. Load Data from S3 and Prepare Data
#
# Load the data from S3, and prepare the data with the target variable as the first column. We will use OHLCV, VWAP, TWAP, SMA5, SMA20, OBC, VROC as the features, and the return of coming bar as the target.
#
# ##### 2. Divide Data into Training and Validation Sets
#
# Divide the data into training and validation datasets.
#
# ##### 3. Train SageMaker Built-in XGBoost Model
#
# Pass the training and validation data to train the SageMaker built-in XGBoost model.
#
# ##### 4. Deploy the Model
#
# Deploy the trained model for inference or further evaluation.

# %% [markdown]
# ## Preparation

# %%
# !pip install ta
# Out:
# Requirement already satisfied: ta in /opt/conda/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from ta) (2.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->ta) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->ta) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->ta) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)

# %% [markdown]
# ## Import and prepare training data

# %%
import sagemaker

# Set up SageMaker session
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()

from sagemaker import get_execution_role
role = get_execution_role()
prefix = 'xgboost-hsbc'
role
# Out:
# 'arn:aws:iam::383386985941:role/service-role/AmazonSageMaker-ExecutionRole-20240909T091637'

# %%
import boto3
import pandas as pd
from io import StringIO

# Set up S3 client
s3 = boto3.client('s3')

# Specify your bucket and file details
bucket_name = 'ai-doc-383386985941'
file_key = 'minutebars.csv'  

# Read the file from S3
obj = s3.get_object(Bucket=bucket_name, Key=file_key)
data = obj['Body'].read().decode('utf-8')

# Convert to DataFrame and only get HSBA.L
df = pd.read_csv(StringIO(data))
df = df[(df['volume'] != 0) & (df['close'] != 0) & (df['twap'] != 0)]


import numpy as np
import ta

# Set bucket as index
df.set_index('bucket', inplace=True)

# Feature engineering
df['returns'] = df['close'].pct_change()
df['SMA_5'] = ta.trend.sma_indicator(df['close'], window=5)
df['SMA_20'] = ta.trend.sma_indicator(df['close'], window=20)
df['OBV'] = ta.volume.on_balance_volume(df['close'], df['volume'])
df['VROC'] = ta.volume.volume_price_trend(df['close'], df['volume'])
df
# Out:
#                      ticker  trades    open    high     low   close   volume  \
# bucket
# 2024-07-01 07:00:00   AAL.L      46  2401.0  2431.5  2401.0  2423.0    72859
# 2024-07-01 07:01:00   AAL.L     128  2425.0  2429.5  2420.0  2425.5    12212
# 2024-07-01 07:02:00   AAL.L      19  2427.5  2427.5  2416.5  2416.5     1546
# 2024-07-01 07:03:00   AAL.L      83  2418.0  2418.5  2410.5  2416.0     8590
# 2024-07-01 07:04:00   AAL.L      90  2419.0  2419.0  2412.0  2412.5    10772
# ...                     ...     ...     ...     ...     ...     ...      ...
# 2024-07-31 15:27:00  ULVR.L      23  4770.0  4772.0  4770.0  4772.0     6003
# 2024-07-31 15:28:00  ULVR.L      44  4772.0  4772.0  4771.0  4771.0    12895
# 2024-07-31 15:29:00  ULVR.L      47  4771.0  4772.0  4770.0  4771.0    12730
# 2024-07-31 15:35:00  ULVR.L       4  4776.0  4776.0  4776.0  4776.0  2109582
# 2024-07-31 15:38:00  ULVR.L       4  4776.0  4776.0  4776.0  4776.0     3489
#
#                             vwap         twap   returns   SMA_5   SMA_20  \
# bucket
# 2024-07-01 07:00:00  2402.990063  2425.252569       NaN     NaN      NaN
# 2024-07-01 07:01:00  2425.881387  2425.991103  0.001032     NaN      NaN
# 2024-07-01 07:02:00  2418.197930  2423.425674 -0.003711     NaN      NaN
# 2024-07-01 07:03:00  2414.251397  2415.928137 -0.000207     NaN      NaN
# 2024-07-01 07:04:00  2415.266153  2415.349853 -0.001449  2418.7      NaN
# ...                          ...          ...       ...     ...      ...
# 2024-07-31 15:27:00  4770.818591  4770.872757  0.000419  4769.8  4763.95
# 2024-07-31 15:28:00  4771.427065  4771.326630 -0.000210  4770.2  4764.65
# 2024-07-31 15:29:00  4770.804399  4770.806618  0.000000  4770.6  4765.40
# 2024-07-31 15:35:00  4776.000000  4776.000000  0.001048  4772.0  4766.35
# 2024-07-31 15:38:00  4776.000000  4776.000000  0.000000  4773.2  4767.25
#
#                            OBV          VROC
# bucket
# 2024-07-01 07:00:00      72859           NaN
# 2024-07-01 07:01:00      85071  1.260008e+01
# 2024-07-01 07:02:00      83525  6.863533e+00
# 2024-07-01 07:03:00      74935  5.086169e+00
# 2024-07-01 07:04:00      64163 -1.051896e+01
# ...                        ...           ...
# 2024-07-31 15:27:00  250233770  5.489619e+06
# 2024-07-31 15:28:00  250220875  5.489616e+06
# 2024-07-31 15:29:00  250233605  5.489616e+06
# 2024-07-31 15:35:00  252343187  5.491827e+06
# 2024-07-31 15:38:00  252346676  5.491827e+06
#
# [179884 rows x 14 columns]

# %%
# Drop NaN values
df.dropna(inplace=True)

# Create target variable (predicting next bar's return)
df['expected_return'] = df['returns'].shift(-1)
return_threshold = 0.0001
df['target'] = np.where(df['expected_return'] > return_threshold, 1, 0)

# Prepare features and target, 'target' to be the first position
desired_cols = ['target', 'open', 'high', 'low', 'close', 'volume', 'vwap', 'twap', 'SMA_5', 'SMA_20', 'OBV', 'VROC']
df = df[desired_cols]
df
# Out:
#                      target    open    high     low   close   volume  \
# bucket
# 2024-07-01 07:19:00       1  2442.5  2442.5  2433.0  2436.5     8103
# 2024-07-01 07:20:00       0  2437.5  2439.0  2437.5  2438.0     1032
# 2024-07-01 07:21:00       0  2438.0  2438.0  2431.5  2436.5     5575
# 2024-07-01 07:22:00       0  2437.0  2437.0  2433.5  2435.0     3198
# 2024-07-01 07:23:00       0  2435.0  2435.0  2421.5  2422.0    21356
# ...                     ...     ...     ...     ...     ...      ...
# 2024-07-31 15:26:00       1  4770.0  4770.0  4770.0  4770.0     4291
# 2024-07-31 15:27:00       0  4770.0  4772.0  4770.0  4772.0     6003
# 2024-07-31 15:28:00       0  4772.0  4772.0  4771.0  4771.0    12895
# 2024-07-31 15:29:00       1  4771.0  4772.0  4770.0  4771.0    12730
# 2024-07-31 15:35:00       0  4776.0  4776.0  4776.0  4776.0  2109582
#
#                             vwap         twap   SMA_5    SMA_20        OBV  \
# bucket
# 2024-07-01 07:19:00  2437.016537  2439.501375  2440.9  2426.450      73171
# 2024-07-01 07:20:00  2438.259205  2437.511347  2439.6  2427.200      74203
# 2024-07-01 07:21:00  2435.326099  2434.813581  2438.6  2427.750      68628
# 2024-07-01 07:22:00  2434.611945  2435.147308  2437.6  2428.675      65430
# 2024-07-01 07:23:00  2427.273296  2428.005198  2433.6  2428.975      44074
# ...                          ...          ...     ...       ...        ...
# 2024-07-31 15:26:00  4770.000000  4770.000000  4769.0  4763.250  250227767
# 2024-07-31 15:27:00  4770.818591  4770.872757  4769.8  4763.950  250233770
# 2024-07-31 15:28:00  4771.427065  4771.326630  4770.2  4764.650  250220875
# 2024-07-31 15:29:00  4770.804399  4770.806618  4770.6  4765.400  250233605
# 2024-07-31 15:35:00  4776.000000  4776.000000  4772.0  4766.350  252343187
#
#                              VROC
# bucket
# 2024-07-01 07:19:00 -1.364295e+01
# 2024-07-01 07:20:00 -1.300761e+01
# 2024-07-01 07:21:00 -1.643768e+01
# 2024-07-01 07:22:00 -1.840648e+01
# 2024-07-01 07:23:00 -1.324221e+02
# ...                           ...
# 2024-07-31 15:26:00  5.489616e+06
# 2024-07-31 15:27:00  5.489619e+06
# 2024-07-31 15:28:00  5.489616e+06
# 2024-07-31 15:29:00  5.489616e+06
# 2024-07-31 15:35:00  5.491827e+06
#
# [179864 rows x 12 columns]

# %%
# Function to save DataFrame to temp file and upload to S3
def save_and_upload(data, bucket, s3key, filename):
    data.to_csv(filename, header=False, index=False)
    boto3.Session().resource("s3").Bucket(bucket).Object(s3key).upload_file(filename)

# %%
# Split your data into train and validation sets
split_point = int(len(df) * 0.8)
train_data = df.iloc[:split_point]
validation_data = df.iloc[split_point:]

# Save and upload train data
train_data_key = f"{prefix}/train/train.csv"
save_and_upload(train_data, bucket,train_data_key , 'train.csv')
train_data_path = f"s3://{bucket}/{train_data_key}"
print(f"training data: {train_data_path}")

# Save and upload validation data
validation_data_key = f"{prefix}/validation/validation.csv"
save_and_upload(validation_data, bucket, validation_data_key, 'validation.csv')
validation_data_path = f"s3://{bucket}/{validation_data_key}"
print(f"validation data: {validation_data_path}")
# Out:
# training data: s3://sagemaker-us-east-1-383386985941/xgboost-hsbc/train/train.csv
# validation data: s3://sagemaker-us-east-1-383386985941/xgboost-hsbc/validation/validation.csv

# %% [markdown]
# ## Parallel Model Training with 20 Instances

# %%
from sagemaker.inputs import TrainingInput

container = sagemaker.image_uris.retrieve("xgboost", sagemaker_session.boto_region_name, "1.7-1")
display(container)

# Set up the XGBoost estimator
xgb_estimator = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=20,
    instance_type="ml.m5.xlarge",
    output_path=f"s3://{bucket}/{prefix}/output",
    sagemaker_session=sagemaker_session
)

xgb_estimator.set_hyperparameters(
    max_depth=6,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    verbosity=0,
    objective="binary:logistic",
    num_round=1000,
)
                            
# Define the input data configuration
train_input = TrainingInput(s3_data=train_data_path, content_type="text/csv")
validation_input = TrainingInput(s3_data=validation_data_path, content_type="text/csv")

# Train the model
xgb_estimator.fit({"train": train_input, "validation": validation_input})
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1'
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2024-09-12-01-45-15-380
# 2024-09-12 01:45:18 Starting - Starting the training job...
# 2024-09-12 01:45:33 Starting - Preparing the instances for training......
# 2024-09-12 01:46:48 Downloading - Downloading input data......
# 2024-09-12 01:47:23 Downloading - Downloading the training image...
# 2024-09-12 01:48:05 Training - Training image download completed. Training in progress.[2024-09-12 01:48:10.014 ip-10-0-104-228.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:10.038 ip-10-0-104-228.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:10:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:10:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:10:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:10:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:10:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:10:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:10:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:10:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:10:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:10:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv4252535238904642070
# [2024-09-12:01:48:10:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:10:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:10:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:10:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:10:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-4773113085812012961
# [2024-09-12:01:48:10:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:10:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:10:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:10:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:10:INFO] Sleeping for 3 sec before retrying
# [2024-09-12 01:48:12.888 ip-10-0-75-154.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.911 ip-10-0-75-154.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12 01:48:12.724 ip-10-0-94-53.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.747 ip-10-0-94-53.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12 01:48:12.632 ip-10-0-73-55.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.654 ip-10-0-73-55.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv8604207313039858866
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12 01:48:12.996 ip-10-0-126-137.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:13.018 ip-10-0-126-137.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12 01:48:12.970 ip-10-0-90-211.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.992 ip-10-0-90-211.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12 01:48:12.936 ip-10-0-89-226.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.957 ip-10-0-89-226.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv1085250274939350338
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12 01:48:12.845 ip-10-0-81-237.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.867 ip-10-0-81-237.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv3643971527588778245
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-8155028161581970721
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12 01:48:11.928 ip-10-0-126-73.ec2.internal:8 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:11.949 ip-10-0-126-73.ec2.internal:8 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:12:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:12:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:12:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:12:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:12:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv2789913627201079632
# [2024-09-12:01:48:12:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:12:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-7878057358915075092
# [2024-09-12:01:48:12:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:12:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:12:INFO] Sleeping for 3 sec before retrying
# [2024-09-12 01:48:12.898 ip-10-0-93-71.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.921 ip-10-0-93-71.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-7953941526713988547
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-8421022658169558974
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12 01:48:11.988 ip-10-0-116-114.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.010 ip-10-0-116-114.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:12:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:12:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:12:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:12:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:12:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:12:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-7631531455969913653
# [2024-09-12:01:48:12:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:12:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv4845098231374919305
# [2024-09-12:01:48:12:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:12:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:12:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:12:INFO] start listen on algo-1:9099
# [2024-09-12:01:48:12:INFO] Rabit slave environment: {'DMLC_TRACKER_URI': 'algo-1', 'DMLC_TRACKER_PORT': 9099}
# [2024-09-12:01:48:12:INFO] Connected to RabitTracker.
# [2024-09-12:01:48:12:INFO] No data received from connection ('10.0.116.114', 47818). Closing.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.126.19', 33828). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.73.55', 33084). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.94.53', 44526). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.81.237', 43488). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.71.93', 59554). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.105.222', 56888). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.89.226', 54040). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.93.71', 55442). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.75.154', 37872). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.67.99', 59736). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.90.211', 49688). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.104.228', 54480). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.126.137', 51164). Closing.
# [2024-09-12:01:48:13:INFO] No data received from connection ('10.0.111.191', 49334). Closing.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-8209557077928872639
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv2823236888933513951
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-7225965531058461362
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-1916772972914020802
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-7794703883986127481
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv8696443917248588616
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv2852585478278478504
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-8668926106648848910
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-9208432730538232942
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv637045667830023969
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:14:INFO] No data received from connection ('10.0.119.237', 41112). Closing.
# [2024-09-12:01:48:14:INFO] No data received from connection ('10.0.82.33', 54682). Closing.
# [2024-09-12 01:48:13.417 ip-10-0-119-237.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:13.439 ip-10-0-119-237.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv3906732852671137999
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-2417834172047976100
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:14:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:14:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12 01:48:12.986 ip-10-0-67-99.ec2.internal:8 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:13.014 ip-10-0-67-99.ec2.internal:8 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-3085240415227730973
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-2805712702111298933
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12 01:48:13.200 ip-10-0-111-191.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:13.227 ip-10-0-111-191.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-364767506074468493
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-7692084954378653850
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12 01:48:14.121 ip-10-0-82-33.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:14.146 ip-10-0-82-33.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:14:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:14:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:14:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:14:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:14:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:14:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:14:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:14:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-3641769549473649056
# [2024-09-12:01:48:14:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:14:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:14:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:14:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv2130117370389231600
# [2024-09-12:01:48:14:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:14:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:14:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:14:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:15:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [2024-09-12:01:48:15:INFO] No data received from connection ('10.0.126.73', 51604). Closing.
# [01:48:16] task NULL got new rank 1
# [2024-09-12:01:48:15:INFO] No data received from connection ('10.0.116.30', 38080). Closing.
# [2024-09-12:01:48:15:INFO] No data received from connection ('10.0.100.109', 50114). Closing.
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.100.109; assign rank 0
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.104.228; assign rank 1
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.105.222; assign rank 2
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.111.191; assign rank 3
# [01:48:16] task NULL got new rank 4
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.116.114; assign rank 4
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.116.30; assign rank 5
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.119.237; assign rank 6
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.126.137; assign rank 7
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.126.19; assign rank 8
# [01:48:16] task NULL got new rank 6
# [01:48:16] task NULL got new rank 10
# [01:48:16] task NULL got new rank 3
# [01:48:17] task NULL got new rank 12
# [01:48:16] task NULL got new rank 7
# [01:48:17] task NULL got new rank 14
# [01:48:16] task NULL got new rank 9
# [01:48:17] task NULL got new rank 18
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.126.73; assign rank 9
# [2024-09-12:01:48:16:INFO] Recieve start signal from 10.0.67.99; assign rank 10
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.71.93; assign rank 11
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.73.55; assign rank 12
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.75.154; assign rank 13
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.81.237; assign rank 14
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.82.33; assign rank 15
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.89.226; assign rank 16
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.90.211; assign rank 17
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.93.71; assign rank 18
# [2024-09-12:01:48:17:INFO] Recieve start signal from 10.0.94.53; assign rank 19
# [2024-09-12:01:48:17:INFO] @tracker All of 20 nodes getting started
# [01:48:17] task NULL got new rank 13
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [01:48:17] task NULL got new rank 15
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [2024-09-12:01:48:18:INFO] Failed to connect to RabitTracker on attempt 0
# [2024-09-12:01:48:18:INFO] Sleeping for 3 sec before retrying
# [2024-09-12:01:48:21:INFO] Connected to RabitTracker.
# [2024-09-12:01:48:21:INFO] Connected to RabitTracker.
# [2024-09-12:01:48:21:INFO] Connected to RabitTracker.
# [01:48:21] task NULL got new rank 7
# [2024-09-12:01:48:21:INFO] Train matrix has 143891 rows and 11 columns
# [2024-09-12:01:48:21:INFO] Validation matrix has 35973 rows
# [2024-09-12 01:48:21.856 ip-10-0-126-137.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-09-12 01:48:21.856 ip-10-0-126-137.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-09-12 01:48:21.857 ip-10-0-126-137.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2024-09-12 01:48:21.857 ip-10-0-126-137.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2024-09-12:01:48:21:INFO] Debug hook created from config
# [01:48:22] task NULL got new rank 18
# [2024-09-12 01:48:12.881 ip-10-0-105-222.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:12.904 ip-10-0-105-222.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:13:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:13:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:13:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:13:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:13:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv2652437214766988433
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:13:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv1674114220585098703
# [2024-09-12:01:48:13:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:13:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:13:INFO] Distributed node training with 20 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12', 'algo-13', 'algo-14', 'algo-15', 'algo-16', 'algo-17', 'algo-18', 'algo-19', 'algo-20']
# [2024-09-12:01:48:13:INFO] Connected to RabitTracker.
# /miniconda3/lib/python3.8/site-packages/xgboost/rabit.py:23: FutureWarning: The xgboost.rabit submodule is marked as deprecated in 1.7 and will be removed in 2.0. Please use xgboost.collective instead.
#   warnings.warn(_deprecation_warning(), FutureWarning)
# [01:48:16] task NULL got new rank 2
# [2024-09-12 01:48:15.379 ip-10-0-100-109.ec2.internal:6 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-09-12 01:48:15.401 ip-10-0-100-109.ec2.internal:6 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-09-12:01:48:15:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-09-12:01:48:15:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-09-12:01:48:15:INFO] No GPUs detected (normal if no gpus installed)
# [2024-09-12:01:48:15:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-09-12:01:48:15:INFO] Determined 0 GPU(s) available on the instance.
# [2024-09-12:01:48:15:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:15:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:15:INFO] File path /opt/ml/input/data/train of input files
# [2024-09-12:01:48:15:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:15:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv7253650833069201716
# [2024-09-12:01:48:15:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:15:INFO] Determined delimiter of CSV input is ','
# [2024-09-12:01:48:15:INFO] File path /opt/ml/input/data/validation of input files
# [2024-09-12:01:48:15:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:15:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv2797901052584381484
# [2024-09-12:01:48:15:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-09-12:01:48:15:INFO] Determined delimiter of CSV input is ','
# ...
# [2024-09-12:01:49:53:INFO] [822]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:53:INFO] [823]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [824]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [825]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [826]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [827]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [828]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [829]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [830]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [831]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [832]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [833]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:54:INFO] [834]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [835]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [836]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [837]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [838]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [839]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [840]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [841]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [842]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:55:INFO] [843]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [844]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [845]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [846]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [847]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [848]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [849]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [850]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [851]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:56:INFO] [852]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [853]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [854]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [855]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [856]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [857]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [858]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [859]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [860]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [861]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [862]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:57:INFO] [863]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [864]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [865]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [866]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [867]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [868]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [869]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [870]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [871]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [872]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:58:INFO] [873]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [874]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [875]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [876]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [877]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [878]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [879]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [880]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [881]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [882]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:49:59:INFO] [883]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [884]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [885]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [886]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [887]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [888]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [889]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [890]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:00:INFO] [891]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:01:INFO] [892]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:01:INFO] [893]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:01:INFO] [894]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:01:INFO] [895]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:01:INFO] [896]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:02:INFO] [897]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:02:INFO] [898]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:02:INFO] [899]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:03:INFO] [900]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:03:INFO] [901]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:03:INFO] [902]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:03:INFO] [903]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:03:INFO] [904]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:03:INFO] [905]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [906]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [907]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [908]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [909]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [910]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [911]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [912]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [913]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [914]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:04:INFO] [915]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [916]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [917]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [918]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [919]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [920]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [921]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [922]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [923]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [924]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:05:INFO] [925]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [926]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [927]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [928]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [929]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [930]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [931]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [932]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [933]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [934]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:06:INFO] [935]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [936]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [937]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [938]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [939]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [940]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [941]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [942]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [943]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [944]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:07:INFO] [945]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [946]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [947]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [948]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [949]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [950]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [951]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [952]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [953]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [954]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:08:INFO] [955]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [956]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [957]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [958]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [959]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [960]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [961]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [962]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [963]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [964]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:09:INFO] [965]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [966]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [967]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [968]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [969]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [970]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [971]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [972]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [973]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [974]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:10:INFO] [975]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [976]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [977]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [978]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [979]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [980]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [981]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [982]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [983]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [984]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:11:INFO] [985]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [986]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [987]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [988]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [989]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [990]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [991]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [992]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [993]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [994]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:12:INFO] [995]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:13:INFO] [996]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:13:INFO] [997]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:13:INFO] [998]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:13:INFO] [999]#011train-logloss:0.65448#011validation-logloss:0.73970
# [2024-09-12:01:50:13:INFO] @tracker All nodes finishes job
# [2024-09-12:01:50:13:INFO] @tracker 110.6145167350769 secs between node start and job finish
#
# 2024-09-12 01:50:31 Uploading - Uploading generated training model
# 2024-09-12 01:50:31 Completed - Training job completed
# Training seconds: 4460
# Billable seconds: 4460

# %% [markdown]
# ## Deploy and invoke the model

# %%
predictor = xgb_estimator.deploy(initial_instance_count=1, instance_type="ml.m5.large")
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2024-09-12-01-26-43-605
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2024-09-12-01-26-43-605
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2024-09-12-01-26-43-605
# -------!

# %%
def generate_signal(predictor, o, h, l, c, v, vwap, twap, sma5, sma20, obv, vroc):
    # Create a numpy array with the input data
    
    input_data = pd.DataFrame({
        'open': [o],
        'high': [h],
        'low': [l],
        'close': [c],
        'volume': [v],
        'vwap': [vwap],
        'twap': [twap],
        'SMA_5': [sma5],
        'SMA_20': [sma20],
        'OBV': [obv],
        'VROC': [vroc]
    })
    input_df = pd.DataFrame(input_data)
    serializer = sagemaker.serializers.CSVSerializer(content_type="text/csv")
    data = serializer.serialize(input_df)
    
    # Get the prediction from the deployed model
    prediction = predictor.predict(data, initial_args={'ContentType': 'text/csv'})
    predictions = prediction.decode("utf-8")
    predictions = np.fromstring(predictions[1:], sep=",")
    
    return predictions[0]

# %%
# test inference for sample data
up_singal = generate_signal(predictor, 704.3,704.6,704.3,704.3,32667,704.422338,704.421387,703.98,702.995,28071850,42606.534711)
print(f"predicted up percentage: {up_singal}")
    
up_singal = generate_signal(predictor, 703.7,704.0,703.7,704.0,20568,703.855100,703.879121,703.74,702.670,27987999,42584.723347)
print(f"predicted up percentage: {up_singal}")
# Out:
# predicted up percentage: 0.36411571502685547
# predicted up percentage: 0.38617801666259766
